# %% [markdown]
# Remove Duplicates from Sorted Array

# %%
class Solution(object):
    def removeDuplicates(self, nums):

        if not nums:
            return 0
        k = 1

        for i in range(1,len(nums)):
            if nums[i] != nums[i-1]:
                nums[k] = nums[i]
                k += 1
        return k

    nums = [0,0,1,1,2]

# %% [markdown]
# Remove Duplicates from Sorted Array 2: Max of two unique elementsare allowed

# %%
class Solution(object):
    def removeDuplicates(self, nums):

        if len(nums)<2 :
            return len(nums)
        k = 2

        for i in range(1,len(nums)):
            if nums[i] != nums[k-2]:
                nums[k] = nums[i]
                k += 1
        return k

    nums = [0,0,0,1,1,1,2,2]

# %% [markdown]
# Sort 0's and 1's, 0's to left and 1's to right

# %%
class Solution(object):
    def sortZeroOne(self, nums):
        left = 0
        right = len(nums) - 1

        while left < right:
            if nums[left] == 0:
                left += 1
            elif nums[right] == 1:
                right -= 1
            else:
                nums[left], nums[right] = nums[right], nums[left]
                left += 1
                right -= 1

        return nums

# %% [markdown]
# 713. Subarray Product Less Than K
#
# Hint
# Given an array of integers nums and an integer k, return the number of contiguous subarrays where the product of all the elements in the subarray is strictly less than k.
# Example 1:
#
# Input: nums = [10,5,2,6], k = 100
# Output: 8
# Explanation: The 8 subarrays that have product less than 100 are:
# [10], [5], [2], [6], [10, 5], [5, 2], [2, 6], [5, 2, 6]
# Note that [10, 5, 2] is not included as the product of 100 is not strictly less than k.

# %%
nums= [10,5,2,6]
k = 100
if k<=1:
    print(0) # print ko return krde in actual leetcode question

left = 0
product = 1
count = 0

for right in range(len(nums)):
    product *= nums[right]

    while product >= k:
        product //= nums[left]
        left += 1

    count += right - left + 1

print(count)
# Out:
# 8
